# %%
# import dependencies
import numpy as np

# randomly generate 2000 latitudes
lats = np.random.uniform(-90,90, size = 2000)
# randomly generate 2000 longitudes
lngs = np.random.uniform(-180,180, size = 2000)

# %%
# using zip() function, zi lats and lngs together as pairs
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# import dependencies
from citipy import citipy
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 770

# %%
# import requests library to obtain API key from config.py
import requests

# Import API key
from config import weather_api_key

# construct basic url for  OpenWeatherMap
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create an empty list to hold the weather data.
city_data = []

# Create counters.
record_count = 1
set_count = 1

# %%
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city. Notice tha t " " is replaced by "+". This is because in the URL, for example, q="Cabo+San+Lucas"
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather['weather'][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Weather Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# cord 20 of Set 7 | atar
# Processing Record 21 of Set 7 | garowe
# Processing Record 22 of Set 7 | umm lajj
# Processing Record 23 of Set 7 | hattiesburg
# Processing Record 24 of Set 7 | kawalu
# Processing Record 25 of Set 7 | tuatapere
# Processing Record 26 of Set 7 | guerrero negro
# Processing Record 27 of Set 7 | charyshskoye
# Processing Record 28 of Set 7 | hirara
# Processing Record 29 of Set 7 | cholet
# Processing Record 30 of Set 7 | kutum
# Processing Record 31 of Set 7 | la ronge
# Processing Record 32 of Set 7 | lakes entrance
# Processing Record 33 of Set 7 | patan
# Processing Record 34 of Set 7 | constitucion
# Processing Record 35 of Set 7 | sur
# Processing Record 36 of Set 7 | pacifica
# Processing Record 37 of Set 7 | sao felix do xingu
# Processing Record 38 of Set 7 | la romana
# Processing Record 39 of Set 7 | rudnichnyy
# Processing Record 40 of Set 7 | dubbo
# Processing Record 41 of Set 7 | hami
# Processing Record 42 of Set 7 | tura
# Processing Record 43 of Set 7 | san luis
# Processing Record 44 of Set 7 | yeppoon
# Processing Record 45 of Set 7 | oyama
# Processing Record 46 of Set 7 | mufulira
# Processing Record 47 of Set 7 | morondava
# Processing Record 48 of Set 7 | sembakung
# Processing Record 49 of Set 7 | viligili
# City not found. Skipping...
# Processing Record 50 of Set 7 | muros
# Processing Record 1 of Set 8 | bartica
# Processing Record 2 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 3 of Set 8 | mpulungu
# Processing Record 4 of Set 8 | mandal
# Processing Record 5 of Set 8 | huangpu
# Processing Record 6 of Set 8 | atasu
# Processing Record 7 of Set 8 | gat
# Processing Record 8 of Set 8 | yago
# Processing Record 9 of Set 8 | trairi
# Processing Record 10 of Set 8 | ballina
# Processing Record 11 of Set 8 | nabire
# Processing Record 12 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 13 of Set 8 | quatre cocos
# Processing Record 14 of Set 8 | miranorte
# City not found. Skipping...
# Processing Record 15 of Set 8 | hamilton
# Processing Record 16 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 17 of Set 8 | ilulissat
# Processing Record 18 of Set 8 | ambagarh chauki
# Processing Record 19 of Set 8 | ibra
# Processing Record 20 of Set 8 | lithgow
# Processing Record 21 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 22 of Set 8 | el alto
# Processing Record 23 of Set 8 | kitimat
# Processing Record 24 of Set 8 | fengzhen
# Processing Record 25 of Set 8 | karratha
# Processing Record 26 of Set 8 | puerto lopez
# Processing Record 27 of Set 8 | haines junction
# Processing Record 28 of Set 8 | adrar
# Processing Record 29 of Set 8 | tautira
# Processing Record 30 of Set 8 | tevaitoa
# Processing Record 31 of Set 8 | roma
# Processing Record 32 of Set 8 | ceska lipa
# Processing Record 33 of Set 8 | lamar
# Processing Record 34 of Set 8 | ancud
# Processing Record 35 of Set 8 | jiwani
# Processing Record 36 of Set 8 | vila franca do campo
# Processing Record 37 of Set 8 | posse
# Processing Record 38 of Set 8 | barabai
# Processing Record 39 of Set 8 | bend
# Processing Record 40 of Set 8 | batemans bay
# Processing Record 41 of Set 8 | puerto leguizamo
# Processing Record 42 of Set 8 | jardim
# Processing Record 43 of Set 8 | horqueta
# Processing Record 44 of Set 8 | deputatskiy
# Processing Record 45 of Set 8 | utiroa
# City not found. Skipping...
# Processing Record 46 of Set 8 | buqayq
# City not found. Skipping...
# Processing Record 47 of Set 8 | hambantota
# Processing Record 48 of Set 8 | ati
# Processing Record 49 of Set 8 | muroran
# Processing Record 50 of Set 8 | hobyo
# Processing Record 1 of Set 9 | katobu
# Processing Record 2 of Set 9 | fevralsk
# City not found. Skipping...
# Processing Record 3 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 4 of Set 9 | maltahohe
# Processing Record 5 of Set 9 | carutapera
# Processing Record 6 of Set 9 | trat
# Processing Record 7 of Set 9 | bontang
# Processing Record 8 of Set 9 | havre-saint-pierre
# Processing Record 9 of Set 9 | dargaville
# Processing Record 10 of Set 9 | ghanzi
# Processing Record 11 of Set 9 | whitianga
# Processing Record 12 of Set 9 | kigoma
# Processing Record 13 of Set 9 | rawson
# Processing Record 14 of Set 9 | portland
# Processing Record 15 of Set 9 | khatanga
# Processing Record 16 of Set 9 | kuytun
# Processing Record 17 of Set 9 | shimoda
# Processing Record 18 of Set 9 | itaituba
# Processing Record 19 of Set 9 | wilbraham
# Processing Record 20 of Set 9 | prince rupert
# Processing Record 21 of Set 9 | danesti
# Processing Record 22 of Set 9 | seminole
# Processing Record 23 of Set 9 | shelburne
# Processing Record 24 of Set 9 | san juan
# Processing Record 25 of Set 9 | pangnirtung
# Processing Record 26 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 27 of Set 9 | kudahuvadhoo
# Processing Record 28 of Set 9 | beloha
# Processing Record 29 of Set 9 | iquique
# Processing Record 30 of Set 9 | miranda
# Processing Record 31 of Set 9 | orumiyeh
# Processing Record 32 of Set 9 | wagar
# Processing Record 33 of Set 9 | komsomolskiy
# Processing Record 34 of Set 9 | nemuro
# Processing Record 35 of Set 9 | lodwar
# Processing Record 36 of Set 9 | odweyne
# Processing Record 37 of Set 9 | virtsu
# Processing Record 38 of Set 9 | wukari
# Processing Record 39 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 40 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 41 of Set 9 | burgeo
# Processing Record 42 of Set 9 | rovinj
# Processing Record 43 of Set 9 | bakchar
# Processing Record 44 of Set 9 | ossora
# Processing Record 45 of Set 9 | rolim de moura
# City not found. Skipping...
# Processing Record 46 of Set 9 | puerto escondido
# Processing Record 47 of Set 9 | thinadhoo
# Processing Record 48 of Set 9 | vostok
# Processing Record 49 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 50 of Set 9 | teguise
# Processing Record 1 of Set 10 | khani
# Processing Record 2 of Set 10 | mocambique
# City not found. Skipping...
# Processing Record 3 of Set 10 | takoradi
# Processing Record 4 of Set 10 | senanga
# Processing Record 5 of Set 10 | puerto madryn
# Processing Record 6 of Set 10 | maroantsetra
# Processing Record 7 of Set 10 | luena
# Processing Record 8 of Set 10 | belomorsk
# Processing Record 9 of Set 10 | bisignano
# Processing Record 10 of Set 10 | college
# Processing Record 11 of Set 10 | kirakira
# Processing Record 12 of Set 10 | loreto
# Processing Record 13 of Set 10 | torbay
# Processing Record 14 of Set 10 | nouadhibou
# Processing Record 15 of Set 10 | zhangye
# Processing Record 16 of Set 10 | juneau
# Processing Record 17 of Set 10 | valdivia
# Processing Record 18 of Set 10 | pinyug
# Processing Record 19 of Set 10 | erzin
# Processing Record 20 of Set 10 | cap malheureux
# Processing Record 21 of Set 10 | kununurra
# Processing Record 22 of Set 10 | virginia beach
# Processing Record 23 of Set 10 | chegdomyn
# Processing Record 24 of Set 10 | tamandare
# Processing Record 25 of Set 10 | barra do bugres
# Processing Record 26 of Set 10 | ayan
# Processing Record 27 of Set 10 | wuwei
# Processing Record 28 of Set 10 | kuldiga
# Processing Record 29 of Set 10 | blackwater
# Processing Record 30 of Set 10 | nyimba
# Processing Record 31 of Set 10 | bilimbay
# Processing Record 32 of Set 10 | tombouctou
# Processing Record 33 of Set 10 | azimur
# City not found. Skipping...
# Processing Record 34 of Set 10 | touros
# Processing Record 35 of Set 10 | lipin bor
# Processing Record 36 of Set 10 | phan thiet
# Processing Record 37 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 38 of Set 10 | pucallpa
# Processing Record 39 of Set 10 | la serena
# Processing Record 40 of Set 10 | sao filipe
# Processing Record 41 of Set 10 | tommot
# Processing Record 42 of Set 10 | sibolga
# Processing Record 43 of Set 10 | yumen
# Processing Record 44 of Set 10 | sitka
# Processing Record 45 of Set 10 | khuzhir
# Processing Record 46 of Set 10 | gumushane
# City not found. Skipping...
# Processing Record 47 of Set 10 | loa janan
# Processing Record 48 of Set 10 | kloulklubed
# Processing Record 49 of Set 10 | mandra
# Processing Record 50 of Set 10 | dongsheng
# Processing Record 1 of Set 11 | simpang
# Processing Record 2 of Set 11 | hokitika
# Processing Record 3 of Set 11 | laibin
# Processing Record 4 of Set 11 | fuling
# Processing Record 5 of Set 11 | kyabe
# Processing Record 6 of Set 11 | kantabanji
# Processing Record 7 of Set 11 | nandyal
# Processing Record 8 of Set 11 | gandajika
# Processing Record 9 of Set 11 | aksarka
# Processing Record 10 of Set 11 | tezu
# Processing Record 11 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 12 of Set 11 | matagami
# Processing Record 13 of Set 11 | talavera
# Processing Record 14 of Set 11 | chimore
# Processing Record 15 of Set 11 | anito
# Processing Record 16 of Set 11 | severo-kurilsk
# Processing Record 17 of Set 11 | hasaki
# Processing Record 18 of Set 11 | kailua
# Processing Record 19 of Set 11 | naro
# Processing Record 20 of Set 11 | tanout
# Processing Record 21 of Set 11 | finschhafen
# Processing Record 22 of Set 11 | beysehir
# Processing Record 23 of Set 11 | xuddur
# Processing Record 24 of Set 11 | camacha
# Processing Record 25 of Set 11 | sosnovka
# Processing Record 26 of Set 11 | xiaoshi
# Processing Record 27 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 28 of Set 11 | konya
# Processing Record 29 of Set 11 | vila
# Processing Record 30 of Set 11 | bengbu
# Processing Record 31 of Set 11 | koslan
# Processing Record 32 of Set 11 | talnakh
# Processing Record 33 of Set 11 | faya
# Processing Record 34 of Set 11 | turan
# Processing Record 35 of Set 11 | isangel
# Processing Record 36 of Set 11 | broome
# Processing Record 37 of Set 11 | bethanien
# Processing Record 38 of Set 11 | nyrob
# Processing Record 39 of Set 11 | ronne
# Processing Record 40 of Set 11 | colares
# Processing Record 41 of Set 11 | daru
# Processing Record 42 of Set 11 | borogontsy
# Processing Record 43 of Set 11 | calamar
# Processing Record 44 of Set 11 | mitsamiouli
# Processing Record 45 of Set 11 | los llanos de aridane
# Processing Record 46 of Set 11 | saint anthony
# Processing Record 47 of Set 11 | edson
# Processing Record 48 of Set 11 | ishigaki
# Processing Record 49 of Set 11 | shu
# Processing Record 50 of Set 11 | port lincoln
# Processing Record 1 of Set 12 | mashhad
# Processing Record 2 of Set 12 | vrangel
# Processing Record 3 of Set 12 | armidale
# Processing Record 4 of Set 12 | muli
# Processing Record 5 of Set 12 | christchurch
# Processing Record 6 of Set 12 | mnogovershinnyy
# Processing Record 7 of Set 12 | rio hato
# Processing Record 8 of Set 12 | zhob
# Processing Record 9 of Set 12 | mandalgovi
# Processing Record 10 of Set 12 | byron bay
# Processing Record 11 of Set 12 | pochutla
# Processing Record 12 of Set 12 | bayburt
# Processing Record 13 of Set 12 | mahadday weyne
# City not found. Skipping...
# Processing Record 14 of Set 12 | carauari
# Processing Record 15 of Set 12 | saint-francois
# Processing Record 16 of Set 12 | kotka
# Processing Record 17 of Set 12 | jatai
# Processing Record 18 of Set 12 | tomatlan
# Processing Record 19 of Set 12 | matara
# Processing Record 20 of Set 12 | lufilufi
# Processing Record 21 of Set 12 | ondorhaan
# City not found. Skipping...
# Processing Record 22 of Set 12 | debre birhan
# Processing Record 23 of Set 12 | upington
# Processing Record 24 of Set 12 | asau
# Processing Record 25 of Set 12 | havoysund
# Processing Record 26 of Set 12 | perth
# Processing Record 27 of Set 12 | sug-aksy
# City not found. Skipping...
# Processing Record 28 of Set 12 | yaan
# Processing Record 29 of Set 12 | nhulunbuy
# Processing Record 30 of Set 12 | najran
# Processing Record 31 of Set 12 | marrakesh
# Processing Record 32 of Set 12 | bolshaya murta
# City not found. Skipping...
# Processing Record 33 of Set 12 | beringovskiy
# Processing Record 34 of Set 12 | batagay
# Processing Record 35 of Set 12 | nouakchott
# Processing Record 36 of Set 12 | san juan de los morros
# Processing Record 37 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 38 of Set 12 | helong
# Processing Record 39 of Set 12 | belyy yar
# Processing Record 40 of Set 12 | kalevala
# Processing Record 41 of Set 12 | paamiut
# Processing Record 42 of Set 12 | taoudenni
# Processing Record 43 of Set 12 | walvis bay
# Processing Record 44 of Set 12 | jabiru
# City not found. Skipping...
# Processing Record 45 of Set 12 | vanimo
# Processing Record 46 of Set 12 | veraval
# Processing Record 47 of Set 12 | lasa
# Processing Record 48 of Set 12 | nizhniy tsasuchey
# Processing Record 49 of Set 12 | kisangani
# Processing Record 50 of Set 12 | urulga
# City not found. Skipping...
# Processing Record 1 of Set 13 | atambua
# Processing Record 2 of Set 13 | tandil
# Processing Record 3 of Set 13 | ardistan
# City not found. Skipping...
# Processing Record 4 of Set 13 | shumikha
# Processing Record 5 of Set 13 | rafaela
# Processing Record 6 of Set 13 | northam
# Processing Record 7 of Set 13 | pokrovsk
# Processing Record 8 of Set 13 | shupiyan
# Processing Record 9 of Set 13 | biak
# Processing Record 10 of Set 13 | kamina
# Processing Record 11 of Set 13 | termiz
# Processing Record 12 of Set 13 | spornoye
# Processing Record 13 of Set 13 | ville-marie
# Processing Record 14 of Set 13 | pitimbu
# Processing Record 15 of Set 13 | aripuana
# Processing Record 16 of Set 13 | dushanbe
# Processing Record 17 of Set 13 | amberley
# Processing Record 18 of Set 13 | marawi
# Processing Record 19 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 20 of Set 13 | ruidoso
# Processing Record 21 of Set 13 | coatesville
# Processing Record 22 of Set 13 | khasan
# Processing Record 23 of Set 13 | auki
# Processing Record 24 of Set 13 | banda aceh
# Processing Record 25 of Set 13 | skjervoy
# Processing Record 26 of Set 13 | troyes
# Processing Record 27 of Set 13 | havelock
# Processing Record 28 of Set 13 | belgrade
# Processing Record 29 of Set 13 | kewanee
# Processing Record 30 of Set 13 | samarai
# Processing Record 31 of Set 13 | horadiz
# Processing Record 32 of Set 13 | hingatungan
# Processing Record 33 of Set 13 | labutta
# City not found. Skipping...
# Processing Record 34 of Set 13 | bachaquero
# Processing Record 35 of Set 13 | fujin
# Processing Record 36 of Set 13 | acarau
# Processing Record 37 of Set 13 | coquimbo
# Processing Record 38 of Set 13 | port hardy
# Processing Record 39 of Set 13 | phalodi
# Processing Record 40 of Set 13 | ozinki
# Processing Record 41 of Set 13 | el sauzal
# Processing Record 42 of Set 13 | storslett
# Processing Record 43 of Set 13 | katsuura
# Processing Record 44 of Set 13 | lalmohan
# Processing Record 45 of Set 13 | whyalla
# Processing Record 46 of Set 13 | novospasskoye
# Processing Record 47 of Set 13 | tucuman
# Processing Record 48 of Set 13 | sambava
# Processing Record 49 of Set 13 | keetmanshoop
# Processing Record 50 of Set 13 | bokoro
# Processing Record 1 of Set 14 | xining
# Processing Record 2 of Set 14 | candelaria
# Processing Record 3 of Set 14 | itanagar
# Processing Record 4 of Set 14 | xique-xique
# Processing Record 5 of Set 14 | talaya
# Processing Record 6 of Set 14 | zhigansk
# Processing Record 7 of Set 14 | lakatoro
# Processing Record 8 of Set 14 | aquiraz
# Processing Record 9 of Set 14 | fukue
# Processing Record 10 of Set 14 | igarka
# Processing Record 11 of Set 14 | mikhaylovka
# Processing Record 12 of Set 14 | rapid valley
# Processing Record 13 of Set 14 | honggang
# Processing Record 14 of Set 14 | deqing
# Processing Record 15 of Set 14 | polunochnoye
# Processing Record 16 of Set 14 | tilichiki
# Processing Record 17 of Set 14 | novoseleznevo
# Processing Record 18 of Set 14 | gloversville
# Processing Record 19 of Set 14 | kovur
# Processing Record 20 of Set 14 | ocho rios
# Processing Record 21 of Set 14 | cangucu
# Processing Record 22 of Set 14 | sakakah
# Processing Record 23 of Set 14 | puerto baquerizo moreno
# Processing Record 24 of Set 14 | scottsburgh
# City not found. Skipping...
# Processing Record 25 of Set 14 | tukrah
# Processing Record 26 of Set 14 | noumea
# Processing Record 27 of Set 14 | nyakahanga
# Processing Record 28 of Set 14 | putina
# Processing Record 29 of Set 14 | tsogni
# Processing Record 30 of Set 14 | jalu
# Processing Record 31 of Set 14 | ilhabela
# Processing Record 32 of Set 14 | ambon
# Processing Record 33 of Set 14 | dzhusaly
# City not found. Skipping...
# Processing Record 34 of Set 14 | bababe
# City not found. Skipping...
# Processing Record 35 of Set 14 | waipawa
# Processing Record 36 of Set 14 | thunder bay
# Processing Record 37 of Set 14 | ramhormoz
# Processing Record 38 of Set 14 | huinan
# Processing Record 39 of Set 14 | mosquera
# Processing Record 40 of Set 14 | tacambaro
# City not found. Skipping...
# Processing Record 41 of Set 14 | mosetse
# Processing Record 42 of Set 14 | khovu-aksy
# Processing Record 43 of Set 14 | berezovyy
# Processing Record 44 of Set 14 | wahpeton
# Processing Record 45 of Set 14 | tazovskiy
# Processing Record 46 of Set 14 | kalabo
# Processing Record 47 of Set 14 | benidorm
# Processing Record 48 of Set 14 | hurghada
# Processing Record 49 of Set 14 | vao
# Processing Record 50 of Set 14 | inhambane
# Processing Record 1 of Set 15 | champerico
# Processing Record 2 of Set 15 | claremore
# Processing Record 3 of Set 15 | saint-paul
# Processing Record 4 of Set 15 | saleaula
# City not found. Skipping...
# Processing Record 5 of Set 15 | alice springs
# Processing Record 6 of Set 15 | rio brilhante
# Processing Record 7 of Set 15 | penzance
# Processing Record 8 of Set 15 | ulety
# Processing Record 9 of Set 15 | maxixe
# Processing Record 10 of Set 15 | fort saint john
# City not found. Skipping...
# Processing Record 11 of Set 15 | dingzhou
# Processing Record 12 of Set 15 | obera
# Processing Record 13 of Set 15 | inongo
# Processing Record 14 of Set 15 | cardoso
# Processing Record 15 of Set 15 | tiruchchirappalli
# Processing Record 16 of Set 15 | redlands
# Processing Record 17 of Set 15 | sistranda
# Processing Record 18 of Set 15 | mullovka
# Processing Record 19 of Set 15 | synya
# Processing Record 20 of Set 15 | chapais
# Processing Record 21 of Set 15 | guiratinga
# Processing Record 22 of Set 15 | tiarei
# Processing Record 23 of Set 15 | pangai
# Processing Record 24 of Set 15 | kosonsoy
# Processing Record 25 of Set 15 | milingimbi
# City not found. Skipping...
# Processing Record 26 of Set 15 | tukuran
# Processing Record 27 of Set 15 | alakurtti
# Processing Record 28 of Set 15 | dwarka
# Processing Record 29 of Set 15 | souris
# Processing Record 30 of Set 15 | grivenskaya
# Processing Record 31 of Set 15 | bosaso
# Processing Record 32 of Set 15 | moreira sales
# Processing Record 33 of Set 15 | pinotepa nacional
# Processing Record 34 of Set 15 | foumban
# Processing Record 35 of Set 15 | caucaia
# Processing Record 36 of Set 15 | paramonga
# Processing Record 37 of Set 15 | hornepayne
# Processing Record 38 of Set 15 | mecca
# Processing Record 39 of Set 15 | abha
# Processing Record 40 of Set 15 | barao de melgaco
# Processing Record 41 of Set 15 | abu samrah
# Processing Record 42 of Set 15 | bengkulu
# Processing Record 43 of Set 15 | merauke
# Processing Record 44 of Set 15 | saint-augustin
# Processing Record 45 of Set 15 | nguiu
# City not found. Skipping...
# Processing Record 46 of Set 15 | luderitz
# Processing Record 47 of Set 15 | tema
# Processing Record 48 of Set 15 | malinovskiy
# Processing Record 49 of Set 15 | victor harbor
# Processing Record 50 of Set 15 | ust-kuyga
# Processing Record 1 of Set 16 | weligama
# Processing Record 2 of Set 16 | volkach
# Processing Record 3 of Set 16 | ayolas
# Processing Record 4 of Set 16 | atbasar
# Processing Record 5 of Set 16 | oktyabrskoye
# Processing Record 6 of Set 16 | khabary
# Processing Record 7 of Set 16 | gay
# Processing Record 8 of Set 16 | palin
# Processing Record 9 of Set 16 | bonham
# Processing Record 10 of Set 16 | darnah
# Processing Record 11 of Set 16 | parras
# City not found. Skipping...
# Processing Record 12 of Set 16 | songea
# Processing Record 13 of Set 16 | zeerust
# Processing Record 14 of Set 16 | xiongzhou
# Processing Record 15 of Set 16 | giresun
# Processing Record 16 of Set 16 | moussoro
# Processing Record 17 of Set 16 | mollendo
# Processing Record 18 of Set 16 | malwan
# City not found. Skipping...
# Processing Record 19 of Set 16 | karakendzha
# City not found. Skipping...
# Processing Record 20 of Set 16 | praia
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# import pandas
import pandas as pd

city_data
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
new_columns = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Weather Description"]
city_data_df = city_data_df[new_columns]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Emerald      AU -23.5333  148.1667     69.35        30           0
# 1      Saldanha      ZA -33.0117   17.9442     65.75        34          29
# 2         Bluff      NZ -46.6000  168.3333     49.80        72          81
# 3     Kyshtovka      RU  56.5550   76.6271     66.16        62          27
# 4       Rikitea      PF -23.1203 -134.9692     76.17        82          77
# 5        Viedma      AR -40.8135  -62.9967     45.46        55           0
# 6        Albany      US  42.6001  -73.9662     72.52        80          34
# 7  Kruisfontein      ZA -34.0033   24.7314     51.66        27           0
# 8  Puerto Ayora      EC  -0.7393  -90.3518     72.55        91          18
# 9   Santo Tomas      PH  14.1079  121.1414     89.58        51         100
#
#    Wind Speed Weather Description
# 0        8.05           clear sky
# 1       20.78    scattered clouds
# 2        4.14       broken clouds
# 3       14.18    scattered clouds
# 4       14.14       broken clouds
# 5        7.76           clear sky
# 6        6.33    scattered clouds
# 7        9.73           clear sky
# 8        3.00          few clouds
# 9        6.38     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
